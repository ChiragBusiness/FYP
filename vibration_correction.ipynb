# %%
#ok so they have just told us that we actually have the accelerometer data as an input, which is in complete contradiction to what they said in the first place
#so we dont need to predict timestep n, prediction may still be valuable for n+ x though

#without access to the simulation it is going to be very difficult to see if the model is working though

# %%
from IPython.display import Image

Image("images/controll_diagram.jpg")

# %%
#so we have to figure out the additonal dac component that is needed to correct for the vibration

#you know we should really just get a simple implementation working first, then we can add complexity

# %%
#simple implimentation

#just find relation between dac input and the n+1 accelerometer reading
 
#ideal accelerometer reading is 0:
#without thinking about the impact of lag:

#calculate required accelerometer 'component' is just the difference between current acelelrometer reading and 0
#then we need to convert this to a dac value
#so we need a model for accelerometer component -> dac value

# %%
#lets actually start in the reverse direction trying to see the relationship between the dac value and the change in accelerometer reading
